# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 載入gemini

# %%
#匯入必要套件

import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
#api key
import os

# 設置環境變數
os.environ["GEMINI_API_KEY"] = "AIzaSyBJjFoHyJx4Us0xDq9rBNrmDr3oU6B8oHE"

# %%
text = "我剛剛問你什麼"

# %%
import requests
import json



def generate_content(prompt, api_key, url):
    # 設置請求的正文
    data = {
        "contents": [{
            "parts": [
                {"text": prompt}
            ]
        }],
        "safetySettings": [
            {
                "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
                "threshold": "BLOCK_ONLY_HIGH"
            }
        ],
        "generationConfig": {
            "stopSequences": [
                "Title"
            ],
            "temperature": 1.0,
            "maxOutputTokens": 800,
            "topP": 0.8,
            "topK": 10
        }
    }
    
    # 發送POST請求
    response = requests.post(url, headers={'Content-Type': 'application/json'}, data=json.dumps(data))
    
    # 檢查響應
    if response.status_code == 200:
        result = response.json()
        return result
    else:
        return f"Request failed with status code {response.status_code}"

# %% [markdown]
# # 讀取報表pdf

# %%
pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 58.7 MB/s eta 0:00:00:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import fitz  # PyMuPDF

# 打開 PDF 文件
pdf_file = "/kaggle/input/gg-inin/FS.pdf"
doc = fitz.open(pdf_file)

# 初始化一個字串變數來儲存 PDF 內容
revenue = ""

# 讀取每一頁的文本並存入變數
for page_num in range(doc.page_count):
    page = doc.load_page(page_num)  # 加載指定頁面
    text = page.get_text()  # 提取頁面上的文本
    revenue += text  # 將文本加到 pdf_text 變數中

# 輸出 PDF 內容
print(pdf_text)
# Out:
# ASSETS
# USD
# NTD
# %
# NTD
# %
# NTD
# %
# Amount
# %
# Amount
# %
# Current Assets
#     Cash and Cash Equivalents
# 59,636
# $
# 1,886,781
# $
# 30.6
#
# 1,799,127
# $
# 30.1
#
# 1,311,807
# $
# 23.9
#
# 87,654
# $
# 4.9
#
# 574,974
# $
# 43.8
#
#     Investments in Marketable Financial Instruments
# 8,876
# 280,819
# 4.6
#
# 249,508
# 4.2
#
# 239,515
# 4.4
#
# 31,311
#
# 12.5
#
# 41,304
# 17.2
#
#     Accounts Receivable
# 7,901
# 249,974
# 4.1
#
# 210,210
# 3.5
#
# 222,824
# 4.1
#
# 39,764
#
# 18.9
#
# 27,150
# 12.2
#
#     Inventories
# 9,257
# 292,884
# 4.7
#
# 272,491
# 4.5
#
# 262,090
# 4.8
#
# 20,393
#
# 7.5
#
# 30,794
# 11.7
#
#     Other Current Assets
# 2,006
# 63,456
# 1.0
#
# 60,322
# 1.0
#
# 46,241
# 0.8
#
# 3,134
#
# 5.2
#
# 17,215
# 37.2
#
#         Total Current Assets
# 87,676
# 2,773,914
# 45.0
#
# 2,591,658
# 43.3
#
#
# 2,082,477
# 38.0
#
# 182,256
#
# 7.0
#
# 691,437
# 33.2
#
# Non-current Assets
#     Long-term Investments
# 4,025
# 127,332
# 2.1
#
# 140,220
# ...

# %%
# 打開 PDF 文件
pdf_file = "/kaggle/input/gg-inin/TSMC 3Q24 Transcript.pdf"
doc = fitz.open(pdf_file)

# 法說會pdf
conference_report = ""

# 讀取每一頁的文本並存入變數
for page_num in range(doc.page_count):
    page = doc.load_page(page_num)  # 加載指定頁面
    text = page.get_text()  # 提取頁面上的文本
    conference_report += text  # 將文本加到 pdf_text 變數中

# 輸出 PDF 內容
print(conference_report)
# Out:
# REFINITIV STREETEVENTS
# EDITED TRANSCRIPT
# 2330.TW - Q3 2024 Taiwan Semiconductor Manufacturing Co Ltd
# Earnings Call (Chinese, English)
# EVENT DATE/TIME: OCTOBER 17, 2024 / 6:00AM GMT
# REFINITIV STREETEVENTS | www.refinitiv.com | Contact Us
# ©2024 Refinitiv. All rights reserved. Republication or redistribution of Refinitiv content, including by framing or similar means, is prohibited without the prior written
# consent of Refinitiv. 'Refinitiv' and the Refinitiv logo are registered trademarks of Refinitiv and its affiliated companies.
# C O R P O R A T E  P A R T I C I P A N T S
# Jeff Su Taiwan Semiconductor Manufacturing Co Ltd - Director of Investor Relations
# Wendell Huang Taiwan Semiconductor Manufacturing Co Ltd - Senior Vice President and Chief Financial Officer
# C.C. Wei Taiwan Semiconductor Manufacturing Co Ltd - Chairman and Chief Executive Officer
# C O N F E R E N C E  C A L L  P A R T I C I P A N T S
# Gokul Hariharan JP Morgan - Analyst
# ...

# %% [markdown]
# # 載入股價資料

# %%
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.2/948.2 kB 12.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 kB 4.2 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.17.8-cp310-cp310-linux_x86_64.whl size=317853 sha256=94e04ad0f57084563a36175199553735a7f2ed770bd1dfc0480366f7bc5da667
#   Stored in directory: /root/.cache/pip/wheels/75/79/e5/8838db0594cc6c587142fd2563356392ade6255c5930411069
# Successfully built peewee
# ...

# %%
import yfinance as yf # yahoo finance 套件

import pandas as pd # 結構化資料處理套件

import datetime as dt # 時間套件

# %%
# 輸入股票代號

stock_id = "2330.TW"

# stock_id = "2357.tw"

# stock_id = "AAPL"

# stock_id = "NVDA"



'''今天往前算幾天'''

# 資料結束時間

#end = dt.date.today()

# output : 2024-09-30

end = dt.date(2024, 12, 5)

# 抓取半年資料（現在-過去180天）

start = end - dt.timedelta(days=300)



'''抓取特定時間'''

# start = dt.datetime(2024, 1, 1)  # 指定的開始日期

# end = dt.datetime(2024, 6, 30)    # 指定的結束日期





# 參數1: 股票代號, 參數2: 開始時間, 參數3: 結束時間

df = yf.download(stock_id, start=start, end=end).reset_index()



df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Date    Adj Close   Close    High     Low    Open     Volume
# Ticker                 2330.TW 2330.TW 2330.TW 2330.TW 2330.TW    2330.TW
# 0      2024-02-15   688.021240   697.0   709.0   693.0   709.0  112945296
# 1      2024-02-16   674.201599   683.0   699.0   683.0   697.0   44232811
# 2      2024-02-19   669.266052   678.0   682.0   674.0   674.0   34408673
# 3      2024-02-20   678.150085   687.0   688.0   675.0   675.0   30166461
# 4      2024-02-21   672.227356   681.0   683.0   678.0   678.0   30564485
# ..            ...          ...     ...     ...     ...     ...        ...
# 193    2024-11-28  1005.000000  1005.0  1005.0   992.0  1005.0   33689956
# 194    2024-11-29   996.000000   996.0  1010.0   994.0   995.0   40094983
# 195    2024-12-02  1035.000000  1035.0  1040.0  1015.0  1020.0   31168404
# 196    2024-12-03  1055.000000  1055.0  1065.0  1055.0  1060.0   43414538
# ...

# %%
columns_data = df.to_dict(orient='list')  # 這會將每一列轉換為對應的列表

# %%
columns_data
# Out:
# {('Date', ''): [Timestamp('2024-02-15 00:00:00'),
#   Timestamp('2024-02-16 00:00:00'),
#   Timestamp('2024-02-19 00:00:00'),
#   Timestamp('2024-02-20 00:00:00'),
#   Timestamp('2024-02-21 00:00:00'),
#   Timestamp('2024-02-22 00:00:00'),
#   Timestamp('2024-02-23 00:00:00'),
#   Timestamp('2024-02-26 00:00:00'),
#   Timestamp('2024-02-27 00:00:00'),
#   Timestamp('2024-02-29 00:00:00'),
#   Timestamp('2024-03-01 00:00:00'),
#   Timestamp('2024-03-04 00:00:00'),
#   Timestamp('2024-03-05 00:00:00'),
#   Timestamp('2024-03-06 00:00:00'),
#   Timestamp('2024-03-07 00:00:00'),
#   Timestamp('2024-03-08 00:00:00'),
#   Timestamp('2024-03-11 00:00:00'),
#   Timestamp('2024-03-12 00:00:00'),
#   Timestamp('2024-03-13 00:00:00'),
#   Timestamp('2024-03-14 00:00:00'),
#   Timestamp('2024-03-15 00:00:00'),
#   Timestamp('2024-03-18 00:00:00'),
#   Timestamp('2024-03-19 00:00:00'),
#   Timestamp('2024-03-20 00:00:00'),
#   Timestamp('2024-03-21 00:00:00'),
# ...

# %% [markdown]
# # 把所有資料結合成prompt 法說會+財報+股價資料

# %%
#把資料直接轉成str
columns_data_str = str(columns_data)

# %%
# 將 columns_data 字典轉換為字符串（這裡使用了 JSON 格式化）
import json


# 組合成完整的 prompt_text
prompt = f"This is the 2330.TW stock. I am providing you with the company's conference report: {conference_report}, revenue report: {revenue}, and stock data: {columns_data_str}. My question is to analyze the outlook of the company and provide a stock price prediction for the next quarter. Please provide your analysis and prediction in Traditional Chinese."


#print(prompt_text)

# %%
# 設置API密鑰和API端點
api_key = "AIzaSyBJjFoHyJx4Us0xDq9rBNrmDr3oU6B8oHE"
url = "https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?key=" + api_key

result = generate_content(prompt, api_key, url)

# %%
text = result['candidates'][0]['content']['parts'][0]['text']
print(text)
# Out:
# ## 台積電 (2330.TW) 後市展望與股價預測分析
#
# 台積電第三季財報表現亮眼，營收及獲利均超出預期，主要受惠於智慧手機及AI相關需求強勁，帶動3奈米及5奈米製程產能利用率提升。第四季展望也相當樂觀，營收預估將較第三季成長13%，年增35%。然而，展望2025年，毛利率將面臨來自海外廠產能爬坡、N3擴產稀釋、台灣電價高漲及製程轉換成本等壓力。
#
# **正面因素：**
#
# * **AI需求持續強勁:**  台積電管理層多次強調AI需求的真實性及長期性，並預期伺服器AI晶片營收將較去年成長逾三倍，佔2024年總營收比例達青少年百分比。這為台積電未來幾年的成長提供強大動力。
# * **先進製程領先:**  台積電在3奈米及5奈米製程的技術領先地位鞏固其市場龍頭地位，並積極研發2奈米及更先進製程，持續保持競爭優勢。
# * **海外擴產穩步推進:**  儘管海外廠產能爬坡初期會稀釋毛利率，但長期來看，有助於分散風險，並滿足全球客戶的多元化需求。亞利桑那廠已開始試產，預計2025年初量產。日本及德國廠也按計劃推進。
# * **自由現金流充沛:**  台積電擁有充沛的自由現金流，為未來投資及股東回饋提供保障，預期股息將持續穩健成長。
#
#
# **負面因素：**
#
# * **毛利率壓力:**  2025年毛利率將面臨多重壓力，包括海外廠產能爬坡稀釋、電價上漲及製程轉換成本等。  管理層已預期海外廠將造成2-3個百分點的毛利率稀釋。
# * **全球經濟下行風險:**  儘管AI需求強勁，但全球經濟仍存在不確定性，PC及手機等傳統市場需求仍相對疲弱，可能影響台積電整體營收表現。
# * **地緣政治風險:**  台積電高度集中在台灣，地緣政治風險仍是潛在威脅。
#
#
# **股價預測:**
#
# 基於以上分析，預期台積電未來幾個季度營收仍將保持穩健增長，但毛利率增長空間有限。  考慮到AI需求的長期性以及台積電在先進製程的領先地位，預期其股價將維持相對強勢。然而，全球經濟及地緣政治的不確定性，也可能造成股價波動。
#
# ...
